# %%
import pandas as pd

# %%
dataset = pd.read_json('dataset.jsonl', encoding='utf-8', lines = True)
dataset.head(5)
# Out:
#                                                 text
# 0  Наша многодетная семья переехала из Калифорнии...  \
# 1           Прохождение DEAD SPACE на русском языке.
# 2        Рацион для похудения на 2500рублей в неделю
# 3  Всем доброго времени суток <br />\nВот такая л...
# 4                            Как вам такое видео)💕 @
#
#                                           url           id
# 0  http://www.youtube.com/watch?v=_UYt9yJFck0  _UYt9yJFck0  \
# 1  http://www.youtube.com/watch?v=ZZDu5IRiI9g  ZZDu5IRiI9g
# 2  http://www.youtube.com/watch?v=VJ0dk0dxRRk  VJ0dk0dxRRk
# 3  http://www.youtube.com/watch?v=Irzr95K6T9A  Irzr95K6T9A
# 4  http://www.youtube.com/watch?v=9-GWe3L8efY  9-GWe3L8efY
#
#                                hash                date root_id parent_id
# 0  008c23470d1454e362218325921370f1 2023-11-05 00:59:59     NaN       NaN
# 1  0051fdc65fa052f78f1f616ea29952b3 2023-11-04 09:00:23     NaN       NaN
# ...

# %%
# Out:
# ['http://www.youtube.com/watch?v=_UYt9yJFck0',
#  'http://www.youtube.com/watch?v=ZZDu5IRiI9g',
#  'http://www.youtube.com/watch?v=VJ0dk0dxRRk',
#  'http://www.youtube.com/watch?v=Irzr95K6T9A',
#  'http://www.youtube.com/watch?v=9-GWe3L8efY',
#  'http://www.youtube.com/watch?v=dJNj3etmShQ',
#  'http://www.youtube.com/watch?v=ABHScKpjdMg',
#  'http://www.youtube.com/watch?v=BI5sGNU7400',
#  'http://www.youtube.com/watch?v=mTrl-YbrVz0',
#  'http://www.youtube.com/watch?v=HhxA9usv_HE',
#  'http://www.youtube.com/watch?v=7ITjMHAVh08',
#  'http://www.youtube.com/watch?v=cb_78Cstvlo',
#  'http://www.youtube.com/watch?v=zxA64u71wEs',
#  'http://www.youtube.com/watch?v=nYU40o7_Z0I',
#  'http://www.youtube.com/watch?v=NzjD8zVoazE',
#  'http://www.youtube.com/watch?v=WNnyyN0tutk',
#  'http://www.youtube.com/watch?v=lquj_aS1xlA',
#  'http://www.youtube.com/watch?v=syvTSuRGvQQ',
#  'http://www.youtube.com/watch?v=NsP2DutJY2M',
#  'http://www.youtube.com/watch?v=IlSCQZlmsnA',
# ...
